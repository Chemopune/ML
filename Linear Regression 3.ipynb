# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
loans_data=pd.read_csv('loansData.csv')
loans_data.head()
# Out:
#        Amount.Requested  Amount.Funded.By.Investors Interest.Rate Loan.Length  \
# 81174             20000                     20000.0         8.90%   36 months
# 99592             19200                     19200.0        12.12%   36 months
# 80059             35000                     35000.0        21.98%   60 months
# 15825             10000                      9975.0         9.99%   36 months
# 33182             12000                     12000.0        11.71%   36 months
#
#              Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 81174  debt_consolidation               14.90%    SC       MORTGAGE
# 99592  debt_consolidation               28.36%    TX       MORTGAGE
# 80059  debt_consolidation               23.81%    CA       MORTGAGE
# 15825  debt_consolidation               14.30%    KS       MORTGAGE
# 33182         credit_card               18.78%    NJ           RENT
#
#        Monthly.Income FICO.Range  Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# ...

# %%
loans_data['Loan.Length'][0:15]
# Out:
# 81174    36 months
# 99592    36 months
# 80059    60 months
# 15825    36 months
# 33182    36 months
# 62403    36 months
# 48808    36 months
# 22090    60 months
# 76404    36 months
# 15867    36 months
# 94971    36 months
# 36911    36 months
# 41200    60 months
# 83869    36 months
# 53853    36 months
# Name: Loan.Length, dtype: object

# %%
loans_data['Interest.Rate'][0:15]
# Out:
# 81174     8.90%
# 99592    12.12%
# 80059    21.98%
# 15825     9.99%
# 33182    11.71%
# 62403    15.31%
# 48808     7.90%
# 22090    17.14%
# 76404    14.33%
# 15867     6.91%
# 94971    19.72%
# 36911    14.27%
# 41200    21.67%
# 83869     8.90%
# 53853     7.62%
# Name: Interest.Rate, dtype: object

# %%
loans_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 81174 to 3116
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Amount.Requested                2500 non-null   int64
#  1   Amount.Funded.By.Investors      2500 non-null   float64
#  2   Interest.Rate                   2500 non-null   object
#  3   Loan.Length                     2500 non-null   object
#  4   Loan.Purpose                    2500 non-null   object
#  5   Debt.To.Income.Ratio            2500 non-null   object
#  6   State                           2500 non-null   object
#  7   Home.Ownership                  2500 non-null   object
#  8   Monthly.Income                  2499 non-null   float64
#  9   FICO.Range                      2500 non-null   object
#  10  Open.CREDIT.Lines               2498 non-null   float64
#  11  Revolving.CREDIT.Balance        2498 non-null   float64
# ...

# %%
loans =pd.read_csv('loan.csv')
loans.head()
# Out:
#     Interest.Rate  FICO.Score  Loan.Length  Monthly.Income  Loan.Amount
# 6           15.31         670           36         4891.67         6000
# 11          19.72         670           36         3575.00         2000
# 12          14.27         665           36         4250.00        10625
# 13          21.67         670           60        14166.67        28000
# 21          21.98         665           36         6666.67        22000

# %%
plt.figure()
loans = pd.read_csv('loan.csv')
fico=loans["FICO.Score"]
fico.hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
plt.figure()
loans = pd.read_csv('loan.csv')
fico=loans["FICO.Score"]
fico.hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
plt.figure()
loans=pd.read_csv('loan.csv')
loans.boxplot('Interest.Rate','FICO.Score')
# Out:
# <AxesSubplot:title={'center':'Interest.Rate'}, xlabel='FICO.Score'>

# %%
plt.figure()
loans=pd.read_csv('loan.csv')
x=loans.boxplot('Interest.Rate','FICO.Score')
x.set_xlabel('FICO Score')
x.set_ylabel('Interest Rate in %')
# Out:
# Text(0, 0.5, 'Interest Rate i %')

# %%
plt.figure()
loans=pd.read_csv('loan.csv')
x=loans.boxplot('Interest.Rate','FICO.Score')

x.set_xticklabels(['630', ' ', '660', ' ', '690', ' ', '720', ' ',  '750', ' ', '780', ' ', '810'])


x.set_xlabel('FICO Score')
x.set_ylabel('Interest Rate in %')

# %%
from pandas.plotting import scatter_matrix

loans=pd.read_csv('loan.csv')

hist_plot = pd.plotting.scatter_matrix(loans, alpha=0.1, color= 'red', figsize=(10,10), diagonal= 'hist')  # updated Commands
